# %%
from intonatang import paper_figures as figs
from intonatang import intonatang as tang
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
fig = figs.fig1()

# %%
fig = figs.fig2()

# %%
fig = figs.fig3()
# Out:
# Invariant electrodes for non-speech, with f0: 117/121, 0.97%
# Invariant electrodes for non-speech, missing f0: 41/49, 0.84%

# %%
fig = figs.fig4()
# Out:
# Corrrelation between actual and abs-only prediction: 0.66, (p=1.21e-296)
# Corrrelation between actual and rel-only prediction: 0.85, (p=0.00e+00)
# Corrrelation between intonation R2 and absolute pitch R2: 0.03, (p=6.68e-01)
# Corrrelation between intonation R2 and relative pitch R2: 0.57, (p=6.79e-17)

# %%
fig = figs.sfig1()

# %%
fig = figs.sfig2_scatterplots()
# Out:
# Corrrelation between mean PSI and Sentence R2: 0.64, (p=1.64e-21)
# Corrrelation between mean PSI and Intonation R2: -0.18, (p=1.59e-02)
# Corrrelation between mean PSI and Speaker R2: -0.15, (p=5.13e-02)

# %%
fig = figs.sfig3()

# %%
fig = figs.sfig4()
# Out:
# Prediction results for subject EC113, chan 167
# Corrrelation between actual and abs-only prediction: 0.55, (p=8.07e-192)
# Corrrelation between actual and rel-only prediction: 0.76, (p=0.00e+00)
# Prediction results for subject EC113, chan 53
# Corrrelation between actual and abs-only prediction: 0.74, (p=0.00e+00)
# Corrrelation between actual and rel-only prediction: 0.85, (p=0.00e+00)

# %%
fig = figs.sfig5()
# Out:
# Prediction results for subject EC129, chan 202
# Corrrelation between actual and abs-only prediction: 0.78, (p=0.00e+00)
# Corrrelation between actual and rel-only prediction: 0.75, (p=0.00e+00)
# Prediction results for subject EC131, chan 195
# Corrrelation between actual and abs-only prediction: 0.68, (p=1.14e-322)
# Corrrelation between actual and rel-only prediction: 0.59, (p=6.09e-225)
# Corrrelation between speaker R2 and absolute pitch R2: 0.79, (p=4.81e-39)
# Corrrelation between speaker R2 and relative pitch R2: 0.21, (p=5.53e-03)
