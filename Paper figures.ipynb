# %%
from intonatang import paper_figures as figs
from intonatang import intonatang as tang
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
fig = figs.fig1()

# %%
fig = figs.fig2()

# %%
fig = figs.fig3()

# %%
fig = figs.fig4()
# Out:
# Corrrelation between actual and abs-only prediction: 0.66, (p=1.21e-296)
# Corrrelation between actual and rel-only prediction: 0.85, (p=0.00e+00)
# Corrrelation between intonation R2 and absolute pitch R2: 0.04, (p=6.51e-01)
# Corrrelation between intonation R2 and relative pitch R2: 0.63, (p=8.44e-16)
